# %%
import re


def validate_form(data: dict):
    data = data or {}
    warnings = []

    required_fields = ("name", "id")
    missing_fields = [field for field in required_fields if not data.get(field)]

    aadhaar = str(data.get("aadhaar", "")).strip()
    if not re.fullmatch(r"\d{12}", aadhaar):
        warnings.append("Invalid Aadhaar number")

    mobile = str(data.get("mobile", "")).strip()
    if not re.fullmatch(r"\d{10}", mobile):
        warnings.append("Invalid mobile number")

    return {
        "valid": not missing_fields and not warnings,
        "missing_fields": missing_fields,
        "warnings": warnings,
        "data": data,
    }
    #Adding an example of how to use the function
if __name__ == "__main__":
    form_data = {
        "name": "John Doe",
        "id": "12345",
        "aadhaar": "123456789012",
        "mobile": "9876543210"
    }
    result = validate_form(form_data)
    print(result)
# Out:
# {'valid': True, 'missing_fields': [], 'warnings': [], 'data': {'name': 'John Doe', 'id': '12345', 'aadhaar': '123456789012', 'mobile': '9876543210'}}
