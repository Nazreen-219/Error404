# %%
import json
import pyaudio
from vosk import Model, KaldiRecognizer

from command_engine import run_command

model = Model("model/vosk-model-small-hi-0.22")
recognizer = KaldiRecognizer(model, 16000)

mic = pyaudio.PyAudio()
stream = mic.open(
    format=pyaudio.paInt16,
    channels=1,
    rate=16000,
    input=True,
    frames_per_buffer=8000,
)

stream.start_stream()
print("Hindi Voice Assistant Running...")

try:
    while True:
        data = stream.read(4000, exception_on_overflow=False)
        if recognizer.AcceptWaveform(data):
            result = json.loads(recognizer.Result())
            text = result.get("text", "")
            print("User said:", text)
            run_command(text)
except KeyboardInterrupt:
    print("Stopping...")
finally:
    stream.stop_stream()
    stream.close()
    mic.terminate()
# Out:
# Hindi Voice Assistant Running...
# User said: हूं
# User said: कई हैं
# User said: कर रहीं
# User said: हेल्लो
# User said: हेलो
# User said: लो
# User said: उतना अच्छा एक्यूरेट नहीं ले रहा है
# User said: डेथ सर्टिफिकेट
# User said: मृत्यु प्रमाण पत्र घोल दोगुना हो रहा
# User said: क्या बंद हो जाती
# User said: अरे चल हाथ ना
# User said: ठीक है
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 29
#      25 while True:
#      27  data = stream.read(4000)
# ---> 29  if recognizer.AcceptWaveform(data):
#      31   result = json.loads(recognizer.Result())
#      33   text = result["text"]
#
# File e:\anaconda3\Lib\site-packages\vosk\__init__.py:182, in KaldiRecognizer.AcceptWaveform(self, data)
#     181 def AcceptWaveform(self, data):
# --> 182     res = _c.vosk_recognizer_accept_waveform(self._handle, data, len(data))
#     183     if res < 0:
#     184         raise Exception("Failed to process waveform")
#
# KeyboardInterrupt:
